# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:/python projects/batting_records.csv")

# %%
df1= pd.read_csv("C:/python projects/keeping_records.csv")

# %%
b = pd.merge(df,df1, on='Player' )
b
# Out:
#                       Player     span_x  matches_x  innings_x  not outs  \
# 0           JC Buttler (ENG)  2021-2022       12.0       12.0       4.0
# 1      Mohammad Rizwan (PAK)  2021-2022       13.0       13.0       2.0
# 2             DP Conway (NZ)  2021-2022       11.0       11.0       3.0
# 3           Litton Das (BAN)  2021-2022       13.0       13.0       0.0
# 4            BKG Mendis (SL)  2022-2022        8.0        8.0       1.0
# 5            LJ Tucker (IRE)  2022-2022        7.0        7.0       2.0
# 6             Q de Kock (SA)  2021-2022        9.0        9.0       1.0
# 7            MH Cross (SCOT)  2021-2022       11.0       11.0       1.0
# 8   Rahmanullah Gurbaz (AFG)  2021-2022        8.0        8.0       0.0
# 9           MDKJ Perera (SL)  2021-2021        8.0        8.0       1.0
# 10             N Pooran (WI)  2021-2021        5.0        5.0       0.0
# 11          SA Edwards (NED)  2022-2022        8.0        8.0       2.0
# ...
